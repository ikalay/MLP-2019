# %% [markdown]
# <a href="https://colab.research.google.com/github/ikalay/kalito/blob/master/Pruebas_con_style_Transfer_Kalaydjian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir /content/outputs
# Out:
# mkdir: cannot create directory ‘/content/outputs’: File exists

# %% [markdown]
# ## Analisis:
#
# - **content_weight/style_weight** del orden $10^{-1}$ (1-10) no presentan variaciones en la imagen generada.
# - **content_weight/style_weight** del orden $10^{-3}$ o menores (1/10000) presentan variaciones en la imagen generada en la salida (mayor peso del estilo puedo notar en las pruebas blanco y negro con  los fotografos en los cielos y en el sector de los ojos en las pruebas con los pintores). Es interesante como siempre el peso mayor es del estilo del referente sobre la imagen de autor.
#
# - La diferencia es evidente invirtiendo la relacion (10-1), la imagen de salida contiene "menos estilo aplicado". Si bien en algunos ejemplos con rostros de personas esto no sucede. Las mejores respuestas de estilo de refente sobre las fotografias de autor, las obtuve con imágenes de paisajes y ciudades, principalmente en cielos y objetos con lineas rectas. Mientras que las últimas dos pruebas con dos obras de los pintores Caravaggio y el pintor argentino Berni, pude notar cambios en los sectores de los ojos y porsupuesto la influencia de estilo de luz en los rostros y los contornos de lineas en colores pastel.
#
# - Cambiar valores de **total_variation_weight** no mostró un cambio significante.
#
# **Imagenes generadas con diferentes configuraciones de peso de style y content se encuentran generadas en diferentes carpeta con su nomenclatura correspondiente**

# %%
from keras.preprocessing.image import load_img, save_img, img_to_array
import numpy as np
import time
import argparse
from scipy.optimize import fmin_l_bfgs_b
from keras.applications import vgg19
from keras import backend as K
from pathlib import Path

# %%
import tensorflow as tf
print(tf.__version__)
tf.compat.v1.disable_eager_execution()
# Out:
# 2.3.0

# %%
base_image_path = Path("/content/autor_1.jpg")
style_reference_image_path = Path("/content/autor_2.jpg")
result_prefix = Path("/content/outputs")
iterations = 100

# %%
total_variation_weight = 0.1
style_weight = 10
content_weight = 1

# %%
# Definimos el tamaño de las imágenes a utilizar
width, height = load_img(base_image_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height)

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %%
img_content = load_img(base_image_path, target_size=(img_nrows, img_ncols))
img_style = load_img(style_reference_image_path, target_size=(img_nrows, img_ncols))

# %%
img_content
# Out:
# <PIL.Image.Image image mode=RGB size=564x400 at 0x7F1795610048>

# %%
img_style
# Out:
# <PIL.Image.Image image mode=RGB size=564x400 at 0x7F17956101D0>

# %%
def deprocess_image(x):
    x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
# get tensor representations of our images
base_image = K.variable(preprocess_image(base_image_path))
style_reference_image = K.variable(preprocess_image(style_reference_image_path))

# %%
combination_image = K.placeholder((1, img_nrows, img_ncols, 3))

# %%
# combine the 3 images into a single Keras tensor
input_tensor = K.concatenate([base_image,
                              style_reference_image,
                              combination_image], axis=0)

# %%
# build the VGG19 network with our 3 images as input
# the model will be loaded with pre-trained ImageNet weights
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet', include_top=False)
print('Model loaded.')
# get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# Model loaded.

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# %%
def style_loss(style, combination):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return K.sum(K.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def total_variation_loss(x):
    assert K.ndim(x) == 4
    a = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, 1:, :img_ncols - 1, :])
    b = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, :img_nrows - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
# Armamos la loss total
loss = K.variable(0.0)
layer_features = outputs_dict['block5_conv2']
base_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss = loss + content_weight * content_loss(base_image_features,
                                            combination_features)

feature_layers = ['block1_conv1', 'block2_conv1',
                  'block3_conv1', 'block4_conv1',
                  'block5_conv1']
                  
for layer_name in feature_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :] 
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss = loss + (style_weight / len(feature_layers)) * sl
loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %%
grads = K.gradients(loss, combination_image)

outputs = [loss]
if isinstance(grads, (list, tuple)):
    outputs += grads
else:
    outputs.append(grads)

f_outputs = K.function([combination_image], outputs)

# %%
def eval_loss_and_grads(x):
    x = x.reshape((1, img_nrows, img_ncols, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.

# %%
class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

# %%
evaluator = Evaluator()

# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # save current generated image
    img = deprocess_image(x.copy())

    #fname = result_prefix / ('output_at_iteration_%d.png' % i)
    fname = result_prefix / ('output_SW%02d_CW%02d_iteration_%02d.png' % (style_weight,content_weight, i))
    save_img(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 8994348000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_00.png
# Iteration 0 completed in 14s
# Start of iteration 1
# Current loss value: 3407492600.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_01.png
# Iteration 1 completed in 6s
# Start of iteration 2
# Current loss value: 2386658000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_02.png
# Iteration 2 completed in 6s
# Start of iteration 3
# Current loss value: 1997850400.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_03.png
# Iteration 3 completed in 6s
# Start of iteration 4
# Current loss value: 1770218000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_04.png
# Iteration 4 completed in 6s
# Start of iteration 5
# Current loss value: 1621231900.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_05.png
# Iteration 5 completed in 6s
# Start of iteration 6
# Current loss value: 1520263000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_06.png
# Iteration 6 completed in 6s
# Start of iteration 7
# Current loss value: 1444579800.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_07.png
# Iteration 7 completed in 6s
# Start of iteration 8
# Current loss value: 1387971000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_08.png
# Iteration 8 completed in 6s
# Start of iteration 9
# Current loss value: 1340366800.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_09.png
# Iteration 9 completed in 6s
# Start of iteration 10
# Current loss value: 1304482000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_10.png
# Iteration 10 completed in 6s
# Start of iteration 11
# Current loss value: 1269466100.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_11.png
# Iteration 11 completed in 6s
# Start of iteration 12
# Current loss value: 1241238000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_12.png
# Iteration 12 completed in 6s
# Start of iteration 13
# Current loss value: 1215710200.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_13.png
# Iteration 13 completed in 6s
# Start of iteration 14
# Current loss value: 1194852500.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_14.png
# Iteration 14 completed in 6s
# Start of iteration 15
# Current loss value: 1175679600.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_15.png
# Iteration 15 completed in 6s
# Start of iteration 16
# Current loss value: 1157607400.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_16.png
# Iteration 16 completed in 6s
# Start of iteration 17
# Current loss value: 1142615000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_17.png
# Iteration 17 completed in 6s
# Start of iteration 18
# Current loss value: 1128646500.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_18.png
# Iteration 18 completed in 6s
# Start of iteration 19
# Current loss value: 1116507100.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_19.png
# Iteration 19 completed in 6s
# Start of iteration 20
# Current loss value: 1105576400.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_20.png
# Iteration 20 completed in 6s
# Start of iteration 21
# Current loss value: 1095128300.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_21.png
# Iteration 21 completed in 6s
# Start of iteration 22
# Current loss value: 1085237600.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_22.png
# Iteration 22 completed in 6s
# Start of iteration 23
# Current loss value: 1076691500.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_23.png
# Iteration 23 completed in 6s
# Start of iteration 24
# Current loss value: 1067909400.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_24.png
# Iteration 24 completed in 6s
# Start of iteration 25
# Current loss value: 1059994560.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_25.png
# Iteration 25 completed in 6s
# Start of iteration 26
# Current loss value: 1052180200.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_26.png
# Iteration 26 completed in 6s
# Start of iteration 27
# Current loss value: 1045221570.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_27.png
# Iteration 27 completed in 6s
# Start of iteration 28
# Current loss value: 1038406460.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_28.png
# Iteration 28 completed in 6s
# Start of iteration 29
# Current loss value: 1031990660.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_29.png
# Iteration 29 completed in 6s
# Start of iteration 30
# Current loss value: 1025882940.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_30.png
# Iteration 30 completed in 6s
# Start of iteration 31
# Current loss value: 1019979140.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_31.png
# Iteration 31 completed in 6s
# Start of iteration 32
# Current loss value: 1014413950.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_32.png
# Iteration 32 completed in 6s
# Start of iteration 33
# Current loss value: 1009310200.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_33.png
# Iteration 33 completed in 6s
# Start of iteration 34
# Current loss value: 1004513300.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_34.png
# Iteration 34 completed in 6s
# Start of iteration 35
# Current loss value: 999536400.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_35.png
# Iteration 35 completed in 6s
# Start of iteration 36
# Current loss value: 994950400.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_36.png
# Iteration 36 completed in 6s
# Start of iteration 37
# Current loss value: 990498900.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_37.png
# Iteration 37 completed in 6s
# Start of iteration 38
# Current loss value: 986069000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_38.png
# Iteration 38 completed in 6s
# Start of iteration 39
# Current loss value: 981912800.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_39.png
# Iteration 39 completed in 6s
# Start of iteration 40
# Current loss value: 977868160.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_40.png
# Iteration 40 completed in 6s
# Start of iteration 41
# Current loss value: 973992700.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_41.png
# Iteration 41 completed in 6s
# Start of iteration 42
# Current loss value: 970163140.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_42.png
# Iteration 42 completed in 6s
# Start of iteration 43
# Current loss value: 966698240.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_43.png
# Iteration 43 completed in 6s
# Start of iteration 44
# Current loss value: 963068900.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_44.png
# Iteration 44 completed in 6s
# Start of iteration 45
# Current loss value: 959779900.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_45.png
# Iteration 45 completed in 6s
# Start of iteration 46
# Current loss value: 956486200.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_46.png
# Iteration 46 completed in 6s
# Start of iteration 47
# Current loss value: 953302400.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_47.png
# Iteration 47 completed in 6s
# Start of iteration 48
# Current loss value: 950424300.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_48.png
# Iteration 48 completed in 6s
# Start of iteration 49
# Current loss value: 947685500.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_49.png
# Iteration 49 completed in 6s
# Start of iteration 50
# Current loss value: 945017150.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_50.png
# Iteration 50 completed in 6s
# Start of iteration 51
# Current loss value: 942317000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_51.png
# Iteration 51 completed in 6s
# Start of iteration 52
# Current loss value: 939725630.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_52.png
# Iteration 52 completed in 6s
# Start of iteration 53
# Current loss value: 937074700.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_53.png
# Iteration 53 completed in 6s
# Start of iteration 54
# Current loss value: 934486300.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_54.png
# Iteration 54 completed in 6s
# Start of iteration 55
# Current loss value: 932131000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_55.png
# Iteration 55 completed in 6s
# Start of iteration 56
# Current loss value: 929868740.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_56.png
# Iteration 56 completed in 6s
# Start of iteration 57
# Current loss value: 927584200.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_57.png
# Iteration 57 completed in 6s
# Start of iteration 58
# Current loss value: 925447400.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_58.png
# Iteration 58 completed in 6s
# Start of iteration 59
# Current loss value: 923326700.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_59.png
# Iteration 59 completed in 6s
# Start of iteration 60
# Current loss value: 921328900.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_60.png
# Iteration 60 completed in 6s
# Start of iteration 61
# Current loss value: 919406400.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_61.png
# Iteration 61 completed in 6s
# Start of iteration 62
# Current loss value: 917515400.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_62.png
# Iteration 62 completed in 6s
# Start of iteration 63
# Current loss value: 915504640.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_63.png
# Iteration 63 completed in 6s
# Start of iteration 64
# Current loss value: 913715200.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_64.png
# Iteration 64 completed in 6s
# Start of iteration 65
# Current loss value: 911925300.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_65.png
# Iteration 65 completed in 6s
# Start of iteration 66
# Current loss value: 910205060.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_66.png
# Iteration 66 completed in 6s
# Start of iteration 67
# Current loss value: 908409600.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_67.png
# Iteration 67 completed in 6s
# Start of iteration 68
# Current loss value: 906671500.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_68.png
# Iteration 68 completed in 6s
# Start of iteration 69
# Current loss value: 904942800.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_69.png
# Iteration 69 completed in 6s
# Start of iteration 70
# Current loss value: 903290400.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_70.png
# Iteration 70 completed in 6s
# Start of iteration 71
# Current loss value: 901714370.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_71.png
# Iteration 71 completed in 6s
# Start of iteration 72
# Current loss value: 900149800.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_72.png
# Iteration 72 completed in 6s
# Start of iteration 73
# Current loss value: 898625500.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_73.png
# Iteration 73 completed in 6s
# Start of iteration 74
# Current loss value: 897085800.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_74.png
# Iteration 74 completed in 6s
# Start of iteration 75
# Current loss value: 895631360.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_75.png
# Iteration 75 completed in 6s
# Start of iteration 76
# Current loss value: 894172100.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_76.png
# Iteration 76 completed in 6s
# Start of iteration 77
# Current loss value: 892752960.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_77.png
# Iteration 77 completed in 6s
# Start of iteration 78
# Current loss value: 891412900.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_78.png
# Iteration 78 completed in 6s
# Start of iteration 79
# Current loss value: 890044200.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_79.png
# Iteration 79 completed in 6s
# Start of iteration 80
# Current loss value: 888695100.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_80.png
# Iteration 80 completed in 6s
# Start of iteration 81
# Current loss value: 887433500.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_81.png
# Iteration 81 completed in 6s
# Start of iteration 82
# Current loss value: 886100740.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_82.png
# Iteration 82 completed in 6s
# Start of iteration 83
# Current loss value: 884909760.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_83.png
# Iteration 83 completed in 6s
# Start of iteration 84
# Current loss value: 883692100.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_84.png
# Iteration 84 completed in 6s
# Start of iteration 85
# Current loss value: 882550600.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_85.png
# Iteration 85 completed in 6s
# Start of iteration 86
# Current loss value: 881440450.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_86.png
# Iteration 86 completed in 6s
# Start of iteration 87
# Current loss value: 880346560.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_87.png
# Iteration 87 completed in 6s
# Start of iteration 88
# Current loss value: 879278400.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_88.png
# Iteration 88 completed in 6s
# Start of iteration 89
# Current loss value: 878204160.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_89.png
# Iteration 89 completed in 6s
# Start of iteration 90
# Current loss value: 877175000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_90.png
# Iteration 90 completed in 6s
# Start of iteration 91
# Current loss value: 876180350.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_91.png
# Iteration 91 completed in 6s
# Start of iteration 92
# Current loss value: 875169600.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_92.png
# Iteration 92 completed in 6s
# Start of iteration 93
# Current loss value: 874163600.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_93.png
# Iteration 93 completed in 6s
# Start of iteration 94
# Current loss value: 873072800.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_94.png
# Iteration 94 completed in 6s
# Start of iteration 95
# Current loss value: 871950660.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_95.png
# Iteration 95 completed in 6s
# Start of iteration 96
# Current loss value: 870872600.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_96.png
# Iteration 96 completed in 6s
# Start of iteration 97
# Current loss value: 869831550.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_97.png
# Iteration 97 completed in 6s
# Start of iteration 98
# Current loss value: 868821700.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_98.png
# Iteration 98 completed in 6s
# Start of iteration 99
# Current loss value: 867821000.0
# Image saved as /content/outputs/output_SW10_CW01_iteration_99.png
# Iteration 99 completed in 6s
